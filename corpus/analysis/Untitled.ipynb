# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('some_database.csv', sep=",", error_bad_lines=False)
d = pd.read_csv("swbdext.csv", sep=",",error_bad_lines=False)
# Out:
# b'Skipping line 32: expected 6 fields, saw 7\nSkipping line 33: expected 6 fields, saw 7\nSkipping line 34: expected 6 fields, saw 7\nSkipping line 35: expected 6 fields, saw 7\nSkipping line 36: expected 6 fields, saw 7\nSkipping line 37: expected 6 fields, saw 7\nSkipping line 38: expected 6 fields, saw 7\nSkipping line 39: expected 6 fields, saw 7\nSkipping line 40: expected 6 fields, saw 7\nSkipping line 41: expected 6 fields, saw 7\nSkipping line 102: expected 6 fields, saw 7\nSkipping line 103: expected 6 fields, saw 7\nSkipping line 104: expected 6 fields, saw 7\nSkipping line 105: expected 6 fields, saw 7\nSkipping line 106: expected 6 fields, saw 7\nSkipping line 107: expected 6 fields, saw 7\nSkipping line 108: expected 6 fields, saw 7\nSkipping line 109: expected 6 fields, saw 7\nSkipping line 110: expected 6 fields, saw 7\nSkipping line 111: expected 6 fields, saw 7\nSkipping line 162: expected 6 fields, saw 11\nSkipping line 163: expected 6 fields, saw 11\nSkipping line 
# ...

# %%
df.head()
# Out:
#                                                                                                             Item\tworkerid\tRating\tPartitive\tStrengthSome\tMention\tSubjecthood\tModification\tSentence\tSentenceLength\tTrial
# 176651:43\t22\t5\tyes\t5.7\tnew\tother\tmodifie...  a contractor friend helped me  uh  with some of the  uh                             foundation work\t14\t1
# 176651:43\t25\t4\tyes\t5.7\tnew\tother\tmodifie...  a contractor friend helped me  uh  with some of the  uh                             foundation work\t14\t1
# 176651:43\t33\t7\tyes\t5.7\tnew\tother\tmodifie...  a contractor friend helped me  uh  with some of the  uh                             foundation work\t14\t1
# 176651:43\t9\t3\tyes\t5.7\tnew\tother\tmodified\ta  a contractor friend helped me  uh  with some of the  uh                             foundation work\t14\t1
# ...

# %%
d.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
